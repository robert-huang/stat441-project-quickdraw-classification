# %%
import tensorflow as tf
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
session = tf.Session(config=config)
# Out:
# C:\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
import numpy as np
import keras.utils.np_utils as kutils
from sklearn.model_selection import train_test_split
import keras.callbacks as callbacks
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import LearningRateScheduler, ModelCheckpoint
from keras.utils import plot_model
from keras.optimizers import SGD
# Out:
# Using TensorFlow backend.

# %%
num_classes = 4

num_reps = 10

# %%
import random
random.seed(123)
import os

# %%
donut = np.load('donut.npy')
apple = np.load('apple.npy')
potato = np.load('potato.npy')
basketball = np.load('basketball.npy')
watermelon = np.load('watermelon.npy')
circle = np.load('circle.npy')
compass = np.load('compass.npy')
soccerball = np.load('soccer ball.npy')
wheel = np.load('wheel.npy')
cookie = np.load('cookie.npy')
classes = [apple, potato, basketball, watermelon, circle, compass, donut, soccerball, wheel, cookie]

# %%
batch_size = 128
epochs = 12

# %%
import keras
from keras.models import Sequential,Input,Model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.layers.normalization import BatchNormalization
from keras.layers.advanced_activations import LeakyReLU

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),activation='linear',input_shape=(28,28,1),padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D((2, 2),padding='same'))
model.add(Conv2D(64, (3, 3), activation='linear',padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D(pool_size=(2, 2),padding='same'))
model.add(Conv2D(128, (3, 3), activation='linear',padding='same'))
model.add(LeakyReLU(alpha=0.1))                  
model.add(MaxPooling2D(pool_size=(2, 2),padding='same'))
model.add(Flatten())
model.add(Dense(128, activation='linear'))
model.add(LeakyReLU(alpha=0.1))                  
model.add(Dense(num_classes, activation='softmax'))

# %%
callbacks = [ModelCheckpoint('weights',
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True,
                            mode='auto')
            ]
model.compile(loss="categorical_crossentropy", optimizer=keras.optimizers.Adam(), metrics=["acc"])

# %% [raw]
# random_classes = sorted(random.sample(range(0, 9), num_classes))
# for i,j in enumerate(random_classes):
#     random_classes[i] = np.c_[classes[j], np.ones(classes[j].shape[0])*i]
# Data = np.concatenate(tuple(random_classes),axis=0)
# X = Data[:,0:784]
# Y = Data[:,784]
# del Data

# %% [raw]
# X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, random_state=42)
# del X, Y
# X_train = X_train.reshape(-1, 28,28, 1)
# X_test = X_test.reshape(-1,28,28,1)
# X_train = X_train.astype('float32')
# X_test = X_test.astype('float32')
# X_train = X_train / 255.
# X_test = X_test / 255.
# y_train = kutils.to_categorical(Y_train)
# y_test = kutils.to_categorical(Y_test)
# X_train,X_valid,y_train,y_valid = train_test_split(X_train, y_train, test_size=0.1, random_state=13)

# %% [raw]
# model.fit(X_train, y_train, batch_size = batch_size, epochs=epochs,
#                    callbacks=callbacks,
#                    validation_data=(X_valid, y_valid))

# %% [raw]
# i = 1
# test_eval[i] = model.evaluate(X_test, y_test, verbose=0)
# print('Test loss:', test_eval[i][0])
# print('Test accuracy:', test_eval[i][1])

# %%
test_eval = [None]*num_reps
used_classes = [None]*num_reps

for r in range(num_reps):
    random_classes = sorted(random.sample(range(0, 9), num_classes))
    used_classes[r] = random_classes
    for i,j in enumerate(random_classes):
        random_classes[i] = np.c_[classes[j], np.ones(classes[j].shape[0])*i]
    Data = np.concatenate(tuple(random_classes),axis=0)
    X = Data[:,0:784]
    Y = Data[:,784]
    del Data

    X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, random_state=42)
    del X, Y
    X_train = X_train.reshape(-1, 28,28, 1)
    X_test = X_test.reshape(-1,28,28,1)
    X_train = X_train.astype('float32')
    X_test = X_test.astype('float32')
    X_train = X_train / 255.
    X_test = X_test / 255.
    y_train = kutils.to_categorical(Y_train)
    y_test = kutils.to_categorical(Y_test)
    X_train,X_valid,y_train,y_valid = train_test_split(X_train, y_train, test_size=0.1, random_state=13)

    model.fit(X_train, y_train, batch_size = batch_size, epochs=epochs,
                       callbacks=callbacks,
                       validation_data=(X_valid, y_valid))

    test_eval[r] = model.evaluate(X_test, y_test, verbose=0)
    print('Test loss (Loop ', r+1, '): ', test_eval[r][0], sep='')
    print('Test accuracy (Loop ', r+1, '): ', test_eval[r][1], sep='')
# Out:
# Train on 386780 samples, validate on 42976 samples
# Epoch 1/12
# 386780/386780 [==============================] - 34s 88us/step - loss: 0.1390 - acc: 0.9527 - val_loss: 0.1093 - val_acc: 0.9641
#
# Epoch 00001: val_acc improved from -inf to 0.96414, saving model to weights
# Epoch 2/12
# 386780/386780 [==============================] - 32s 83us/step - loss: 0.0976 - acc: 0.9662 - val_loss: 0.0976 - val_acc: 0.9672
#
# Epoch 00002: val_acc improved from 0.96414 to 0.96724, saving model to weights
# Epoch 3/12
# 386780/386780 [==============================] - 32s 83us/step - loss: 0.0869 - acc: 0.9700 - val_loss: 0.0924 - val_acc: 0.9683
#
# Epoch 00003: val_acc improved from 0.96724 to 0.96828, saving model to weights
# Epoch 4/12
# 386780/386780 [==============================] - 32s 83us/step - loss: 0.0788 - acc: 0.9726 - val_loss: 0.0898 - val_acc: 0.9697
#
# Epoch 00004: val_acc improved from 0.96828 to 0.96973, saving model to weights
# Epoch 5/12
# 386780/386780 [==============================] - 32s 83us/step - loss: 0.0707 - acc: 0.9751 - val_loss: 0.0991 - val_acc: 0.9680
#
# Epoch 00005: val_acc did not improve
# Epoch 6/12
# 386780/386780 [==============================] - 32s 83us/step - loss: 0.0633 - acc: 0.9780 - val_loss: 0.1013 - val_acc: 0.9674
#
# Epoch 00006: val_acc did not improve
# Epoch 7/12
# 386780/386780 [==============================] - 32s 83us/step - loss: 0.0560 - acc: 0.9806 - val_loss: 0.1062 - val_acc: 0.9697
#
# Epoch 00007: val_acc did not improve
# Epoch 8/12
# 386780/386780 [==============================] - 32s 83us/step - loss: 0.0501 - acc: 0.9824 - val_loss: 0.1174 - val_acc: 0.9668
#
# Epoch 00008: val_acc did not improve
# Epoch 9/12
# 386780/386780 [==============================] - 32s 83us/step - loss: 0.0450 - acc: 0.9844 - val_loss: 0.1169 - val_acc: 0.9684
#
# Epoch 00009: val_acc did not improve
# Epoch 10/12
# 386780/386780 [==============================] - 32s 82us/step - loss: 0.0409 - acc: 0.9858 - val_loss: 0.1363 - val_acc: 0.9670
#
# Epoch 00010: val_acc did not improve
# Epoch 11/12
# 386780/386780 [==============================] - 32s 82us/step - loss: 0.0380 - acc: 0.9869 - val_loss: 0.1426 - val_acc: 0.9672
#
# Epoch 00011: val_acc did not improve
# Epoch 12/12
#
# Epoch 00010: val_acc did not improve
# Epoch 11/12
# 400266/400266 [==============================] - 38s 94us/step - loss: 0.0388 - acc: 0.9855 - val_loss: 0.2079 - val_acc: 0.9494
#
# Epoch 00011: val_acc did not improve
# Epoch 12/12
# 400266/400266 [==============================] - 40s 101us/step - loss: 0.0344 - acc: 0.9871 - val_loss: 0.2162 - val_acc: 0.9495
#
# Epoch 00012: val_acc did not improve
# Test loss (Loop 9): 0.23458300451738842
# Test accuracy (Loop 9): 0.9472320906597113
# Train on 383922 samples, validate on 42658 samples
# Epoch 1/12
# 383922/383922 [==============================] - 34s 88us/step - loss: 0.1419 - acc: 0.9565 - val_loss: 0.1192 - val_acc: 0.9613
#
# Epoch 00001: val_acc did not improve
# Epoch 2/12
# 383922/383922 [==============================] - 32s 84us/step - loss: 0.1034 - acc: 0.9664 - val_loss: 0.1143 - val_acc: 0.9632
#
# Epoch 00002: val_acc did not improve
# Epoch 3/12
# 383922/383922 [==============================] - 32s 84us/step - loss: 0.0895 - acc: 0.9704 - val_loss: 0.1157 - val_acc: 0.9646
#
# Epoch 00003: val_acc did not improve
# Epoch 4/12
# 383922/383922 [==============================] - 32s 84us/step - loss: 0.0787 - acc: 0.9739 - val_loss: 0.1171 - val_acc: 0.9637
#
# Epoch 00004: val_acc did not improve
# Epoch 5/12
# 383922/383922 [==============================] - 32s 84us/step - loss: 0.0693 - acc: 0.9769 - val_loss: 0.1316 - val_acc: 0.9616
#
# Epoch 00005: val_acc did not improve
# Epoch 6/12
# 383922/383922 [==============================] - 33s 85us/step - loss: 0.0612 - acc: 0.9796 - val_loss: 0.1405 - val_acc: 0.9614
#
# Epoch 00006: val_acc did not improve
# Epoch 7/12
# 383922/383922 [==============================] - 33s 86us/step - loss: 0.0547 - acc: 0.9817 - val_loss: 0.1493 - val_acc: 0.9620
#
# Epoch 00007: val_acc did not improve
# Epoch 8/12
# 383922/383922 [==============================] - 33s 86us/step - loss: 0.0489 - acc: 0.9837 - val_loss: 0.1583 - val_acc: 0.9616
#
# Epoch 00008: val_acc did not improve
# Epoch 9/12
# 383922/383922 [==============================] - 33s 86us/step - loss: 0.0449 - acc: 0.9848 - val_loss: 0.1718 - val_acc: 0.9612
#
# Epoch 00009: val_acc did not improve
# Epoch 10/12
# 383922/383922 [==============================] - 33s 86us/step - loss: 0.0419 - acc: 0.9859 - val_loss: 0.1865 - val_acc: 0.9610
#
# Epoch 00010: val_acc did not improve
# Epoch 11/12
# 383922/383922 [==============================] - 33s 86us/step - loss: 0.0386 - acc: 0.9869 - val_loss: 0.1938 - val_acc: 0.9602
#
# Epoch 00011: val_acc did not improve
# Epoch 12/12
# 383922/383922 [==============================] - 33s 86us/step - loss: 0.0363 - acc: 0.9876 - val_loss: 0.2034 - val_acc: 0.9596
#
# Epoch 00012: val_acc did not improve
# Test loss (Loop 10): 0.19572734699949013
# Test accuracy (Loop 10): 0.9613202681800329

# %%
Loss = np.array(test_eval)[:,0]
Accuracy = np.array(test_eval)[:,1]
print('Average Test loss:', np.mean(Loss))
print('Average Test accuracy:', np.mean(Accuracy))
# Out:
# Average Test loss: 0.23376502876343896
# Average Test accuracy: 0.9447253970790193
